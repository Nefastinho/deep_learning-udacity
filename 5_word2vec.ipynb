# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
print('Done.')
# Out:
# Done.

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
print('Done.')
# Out:
# Found and verified text8.zip
# Done.

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
print('Done.')
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]
# Done.

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
print('Done.')
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'originated', 'term', 'as', 'of', 'term', 'originated']
# Done.

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
  print('Done.')
# Out:
# Done.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
print('Done.')
# Out:
# Initialized
# Average loss at step 0: 8.004869
# Nearest to been: electrified, shir, brushed, disengage, shrunk, sorenson, retreat, fen,
# Nearest to state: guidance, rheumatoid, architecturally, zeeland, immediate, hco, imposing, chicken,
# Nearest to about: effectively, vortigern, progenitors, moabite, codify, enchanted, voiceover, holstein,
# Nearest to an: serialism, houdini, pass, sessions, connectivity, courthouse, joins, formless,
# Nearest to there: cav, mlm, nebraska, vma, pockets, cleaner, kritik, anni,
# Nearest to by: ironclad, vicksburg, vivien, tls, appel, pancho, neutrality, deliveries,
# Nearest to who: pittsburg, wg, issuer, parked, microfluidics, vanguard, conservation, kanal,
# Nearest to new: crist, godel, arndt, abyssinian, quadrivium, subpixels, sequel, synod,
# Nearest to no: musicals, docklands, hydrocodone, wither, affricate, interior, telephones, thick,
# Nearest to many: weiser, acquiesced, aus, unilateral, doctorates, wheelbase, nation, mmc,
# Nearest to th: pain, stags, bulgar, inflammation, digesting, epimorphism, mcintosh, autonomist,
# Nearest to would: greenspan, arlen, dylan, competence, issn, drown, gai, encrypt,
# Nearest to during: lymph, external, propane, nakano, more, bologna, vaults, jun,
# Nearest to most: abortive, pohnpei, selamat, visualize, stabilized, mits, horst, onlookers,
# Nearest to this: dactylic, agency, rammed, arr, westmoreland, harpoon, horseshoe, trader,
# Nearest to his: monistic, wachowski, cplp, stillborn, dobson, casanova, thx, fundamento,
# Average loss at step 2000: 4.379213
# Average loss at step 4000: 3.868651
# Average loss at step 6000: 3.788909
# Average loss at step 8000: 3.696230
# Average loss at step 10000: 3.617983
# Nearest to been: sometimes, be, sorenson, was, electrified, are, originate, anything,
# Nearest to state: chicken, guidance, hco, cricket, imposing, immediate, zeeland, lehmann,
# Nearest to about: liberator, asian, film, flywheel, procol, klaproth, bissette, chivalry,
# Nearest to an: connectivity, the, devolution, courthouse, houdini, pitfalls, serialism, replicas,
# Nearest to there: it, cav, they, still, sovereign, hurricanes, tapioca, not,
# Nearest to by: was, carving, with, as, solo, mothra, satr, at,
# Nearest to who: he, she, tamara, which, and, stifled, microfluidics, they,
# Nearest to new: godel, raytheon, wally, inhibit, decrease, earmarked, cloves, maimonides,
# Nearest to no: comnena, musicals, docklands, hydrocodone, request, bicameral, thick, wither,
# Nearest to many: some, moulton, several, most, dore, wanna, non, wheelbase,
# Nearest to th: epimorphism, bulgar, cts, vandal, inflammation, ogle, wrought, nestorian,
# Nearest to would: could, can, lowland, to, must, taff, intimate, might,
# Nearest to during: first, in, external, compass, nanosystems, at, woodcut, powell,
# Nearest to most: abortive, stabilized, landry, peculiarity, many, shreck, world, czechoslovakia,
# Nearest to this: which, the, it, changes, posterity, abrasive, noord, horseshoe,
# Nearest to his: their, her, the, s, its, thx, fabricated, notify,
# Average loss at step 12000: 3.604778
# Average loss at step 14000: 3.569756
# Average loss at step 16000: 3.416438
# Average loss at step 18000: 3.458834
# Average loss at step 20000: 3.543382
# Nearest to been: be, already, were, was, ineffable, by, never, parker,
# Nearest to state: chicken, imposing, stimson, guidance, tsh, rheumatoid, hco, lehmann,
# Nearest to about: liberator, lamont, procol, espousing, letters, compasses, sufficient, enchanted,
# Nearest to an: connectivity, houdini, courthouse, vlaams, the, surpass, mutation, pitfalls,
# Nearest to there: it, they, which, he, still, often, cav, but,
# Nearest to by: was, be, were, in, with, carving, ratchet, for,
# Nearest to who: he, which, she, also, they, tamara, stifled, fenway,
# Nearest to new: inhibit, godel, potomac, raytheon, wally, mena, decrease, bolshevik,
# Nearest to no: a, hydrocodone, comnena, bicameral, musicals, voris, banned, docklands,
# Nearest to many: some, several, all, these, most, other, moulton, dore,
# Nearest to th: epimorphism, bulgar, vandal, dsn, rd, sumatra, inflammation, ogle,
# Nearest to would: could, will, can, may, must, might, should, lowland,
# Nearest to during: in, at, through, woodcut, orfeo, championing, first, compass,
# Nearest to most: more, many, some, all, landry, stabilized, abortive, world,
# Nearest to this: it, which, the, another, that, troyes, its, posterity,
# Nearest to his: their, her, its, the, organometallic, thx, fibonacci, establishments,
# Average loss at step 22000: 3.502405
# Average loss at step 24000: 3.487688
# Average loss at step 26000: 3.485596
# Average loss at step 28000: 3.480097
# Average loss at step 30000: 3.503461
# Nearest to been: be, were, was, become, already, ineffable, had, officially,
# Nearest to state: chicken, stimson, hco, tsh, imposing, rheumatoid, ancona, affected,
# Nearest to about: liberator, anthropomorphized, letters, sufficient, compasses, only, trackless, enchanted,
# Nearest to an: houdini, connectivity, courthouse, vlaams, surpass, sabine, defences, devolution,
# Nearest to there: they, it, still, he, damme, we, often, now,
# Nearest to by: under, with, were, was, liking, wavetable, from, ratchet,
# Nearest to who: he, she, they, which, also, tamara, now, dungeons,
# Nearest to new: twinning, mena, second, potomac, faroes, biomass, raytheon, treason,
# Nearest to no: any, hydrocodone, comnena, a, voris, musicals, not, there,
# Nearest to many: some, several, these, most, all, various, cabo, dore,
# Nearest to th: rd, bc, epimorphism, vandal, nd, bulgar, inflammation, dz,
# Nearest to would: will, could, can, may, must, might, should, lowland,
# Nearest to during: in, at, after, on, championing, through, since, woodcut,
# Nearest to most: many, more, some, use, landry, all, libertarian, lysine,
# Nearest to this: which, it, what, that, another, the, ceding, any,
# Nearest to his: her, their, its, the, s, organometallic, lots, thx,
# Average loss at step 32000: 3.505605
# Average loss at step 34000: 3.493767
# Average loss at step 36000: 3.455833
# Average loss at step 38000: 3.307088
# Average loss at step 40000: 3.426739
# Nearest to been: be, become, was, already, were, hevelius, had, officially,
# Nearest to state: government, hco, stimson, chicken, ancona, impassioned, tsh, rheumatoid,
# Nearest to about: anthropomorphized, liberator, keynesianism, hundred, trackless, vanir, slaying, answerable,
# Nearest to an: devolution, courthouse, houdini, connectivity, the, vlaams, mutation, surpass,
# Nearest to there: it, they, still, he, sometimes, now, often, also,
# Nearest to by: solo, as, wavetable, pancho, nigsberg, carving, with, yew,
# Nearest to who: he, which, she, also, often, that, they, now,
# Nearest to new: potomac, applicants, bolshevik, second, biomass, test, godel, faroes,
# Nearest to no: any, hydrocodone, ludo, there, comnena, ramanujan, musicals, banned,
# Nearest to many: some, several, these, various, most, those, both, all,
# Nearest to th: rd, bc, epimorphism, vandal, altering, dz, nd, ifr,
# Nearest to would: could, will, may, can, might, should, must, did,
# Nearest to during: after, at, in, through, before, on, while, since,
# Nearest to most: more, many, some, use, less, all, libertarian, both,
# Nearest to this: it, which, the, that, another, some, mortally, what,
# Nearest to his: her, their, its, the, our, gioacchino, s, your,
# Average loss at step 42000: 3.436408
# Average loss at step 44000: 3.455300
# Average loss at step 46000: 3.450151
# Average loss at step 48000: 3.356742
# Average loss at step 50000: 3.383672
# Nearest to been: become, be, already, was, were, ineffable, had, pron,
# Nearest to state: hco, stimson, rheumatoid, impassioned, deck, ancona, government, nebulae,
# Nearest to about: anthropomorphized, slaying, liberator, answerable, hundred, keynesianism, dealt, trackless,
# Nearest to an: the, mutation, houdini, vlaams, devolution, courthouse, baskets, sessions,
# Nearest to there: it, they, he, still, often, now, sometimes, generally,
# Nearest to by: ratchet, solo, carving, was, talked, duran, under, with,
# Nearest to who: he, which, she, often, also, now, never, they,
# Nearest to new: faroes, biomass, great, memberships, second, potomac, treason, topple,
# Nearest to no: any, ramanujan, hydrocodone, yerushalmi, ludo, a, subsumed, patterson,
# Nearest to many: some, several, these, various, numerous, most, both, those,
# Nearest to th: bc, rd, dz, inflammation, vandal, epimorphism, second, ce,
# Nearest to would: will, could, can, may, might, must, should, did,
# Nearest to during: after, at, when, in, while, although, woodcut, before,
# Nearest to most: more, many, less, some, use, very, drags, beaton,
# Nearest to this: which, it, the, some, there, he, schumacher, that,
# Nearest to his: their, her, its, our, my, the, him, your,
# Average loss at step 52000: 3.435641
# Average loss at step 54000: 3.427907
# Average loss at step 56000: 3.437580
# Average loss at step 58000: 3.396741
# Average loss at step 60000: 3.391510
# Nearest to been: become, be, already, was, had, were, mycological, pron,
# Nearest to state: government, ancona, rheumatoid, hco, deck, importance, stimson, deimos,
# Nearest to about: anthropomorphized, compasses, answerable, liberator, slaying, letters, bluegrass, biscuit,
# Nearest to an: mutation, vlaams, devolution, rho, replicas, houdini, courthouse, the,
# Nearest to there: it, they, still, often, now, he, this, sometimes,
# Nearest to by: through, solo, prodigious, nigsberg, dk, ratchet, under, without,
# Nearest to who: she, he, now, often, which, never, also, that,
# Nearest to new: potomac, faroes, mena, previous, biomass, brassiere, ephesus, applicants,
# Nearest to no: any, ramanujan, banned, little, dodgson, a, without, hander,
# Nearest to many: some, several, various, these, most, numerous, both, all,
# Nearest to th: bc, rd, dz, nd, four, epimorphism, ce, ssbn,
# Nearest to would: could, will, may, can, might, should, must, did,
# Nearest to during: after, although, before, in, at, following, when, within,
# Nearest to most: many, more, some, less, use, libertarian, beaton, among,
# Nearest to this: which, it, that, there, some, the, another, organisers,
# Nearest to his: her, their, its, our, my, the, churchill, your,
# Average loss at step 62000: 3.240824
# Average loss at step 64000: 3.258547
# Average loss at step 66000: 3.401555
# Average loss at step 68000: 3.400263
# Average loss at step 70000: 3.360732
# Nearest to been: become, be, was, already, were, repeatedly, had, remained,
# Nearest to state: government, hco, states, ancona, city, rheumatoid, deck, stimson,
# Nearest to about: anthropomorphized, compasses, slaying, dealt, seamus, gorges, biscuit, answerable,
# Nearest to an: mutation, houdini, vlaams, devolution, replicas, the, redundancy, courthouse,
# Nearest to there: they, it, still, he, generally, we, sometimes, she,
# Nearest to by: through, oprah, ratchet, be, from, solo, using, bacterium,
# Nearest to who: she, he, warfield, which, now, generally, often, that,
# Nearest to new: potomac, faroes, aristocrats, biomass, previous, treason, applicants, memberships,
# Nearest to no: any, little, dodgson, ramanujan, there, without, banned, subsumed,
# Nearest to many: some, several, various, these, numerous, most, all, both,
# Nearest to th: bc, rd, dz, second, bce, ssbn, ce, nd,
# Nearest to would: will, could, may, can, should, might, must, did,
# Nearest to during: after, in, before, through, within, until, at, although,
# Nearest to most: more, many, less, some, use, beaton, all, among,
# Nearest to this: which, it, another, the, that, there, some, bead,
# Nearest to his: her, their, its, our, my, caitlin, your, whose,
# Average loss at step 72000: 3.379741
# Average loss at step 74000: 3.346215
# Average loss at step 76000: 3.318454
# Average loss at step 78000: 3.351311
# Average loss at step 80000: 3.378345
# Nearest to been: become, be, was, repeatedly, were, remained, already, had,
# Nearest to state: government, states, city, hco, ancona, dek, deck, rheumatoid,
# Nearest to about: anthropomorphized, gorges, slaying, biscuit, negotiating, pal, compasses, letters,
# Nearest to an: mutation, houdini, serialism, courthouse, sabine, locales, bilge, vlaams,
# Nearest to there: they, it, he, still, often, she, we, generally,
# Nearest to by: ratchet, through, pancho, pygmies, oprah, newly, solo, wavetable,
# Nearest to who: he, she, which, often, they, fetal, warfield, actually,
# Nearest to new: faroes, previous, vives, potomac, origination, mena, applicants, godel,
# Nearest to no: little, any, dodgson, ramanujan, hander, juneau, without, there,
# Nearest to many: some, several, various, numerous, these, both, most, those,
# Nearest to th: bc, rd, bce, dz, nd, one, second, ad,
# Nearest to would: will, could, can, may, might, should, must, did,
# Nearest to during: after, in, when, although, before, through, under, within,
# Nearest to most: more, less, many, some, sodom, especially, beaton, ecological,
# Nearest to this: it, which, itself, the, what, arousing, there, another,
# Nearest to his: her, their, its, our, my, your, caitlin, the,
# Average loss at step 82000: 3.405946
# Average loss at step 84000: 3.407359
# Average loss at step 86000: 3.389710
# Average loss at step 88000: 3.356387
# Average loss at step 90000: 3.363286
# Nearest to been: become, be, already, remained, repeatedly, was, being, were,
# Nearest to state: city, government, ancona, hco, states, rheumatoid, deck, marion,
# Nearest to about: anthropomorphized, gorges, slaying, beyond, biscuit, unbundling, answerable, over,
# Nearest to an: mutation, houdini, rho, courthouse, vlaams, serialism, locales, judgements,
# Nearest to there: they, it, he, we, still, she, generally, therefore,
# Nearest to by: through, with, using, ratchet, when, under, nigsberg, narrators,
# Nearest to who: he, she, often, which, generally, also, warfield, actually,
# Nearest to new: previous, vives, origination, different, ulster, biomass, faroes, mena,
# Nearest to no: any, little, ramanujan, dodgson, yerushalmi, only, nothing, juneau,
# Nearest to many: several, some, numerous, various, these, most, all, both,
# Nearest to th: bc, rd, bce, one, nd, three, dz, seven,
# Nearest to would: will, could, might, can, may, should, must, did,
# Nearest to during: after, in, before, through, until, while, when, under,
# Nearest to most: more, less, many, some, beaton, among, especially, use,
# Nearest to this: it, which, itself, another, some, the, any, adversely,
# Nearest to his: her, their, its, our, your, my, caitlin, the,
# Average loss at step 92000: 3.396233
# Average loss at step 94000: 3.256449
# Average loss at step 96000: 3.357820
# Average loss at step 98000: 3.240726
# Average loss at step 100000: 3.356497
# Nearest to been: become, be, already, remained, was, repeatedly, evolved, had,
# Nearest to state: city, government, ancona, hco, states, marion, deck, dek,
# Nearest to about: anthropomorphized, dealt, gorges, beyond, around, slaying, least, phony,
# Nearest to an: mutation, houdini, devolution, courthouse, connectivity, wracked, vlaams, locales,
# Nearest to there: they, it, he, we, now, generally, still, sometimes,
# Nearest to by: through, pygmies, ratchet, when, including, ferns, during, ghostbusters,
# Nearest to who: he, she, frequently, actually, often, now, that, which,
# Nearest to new: faroes, previous, biomass, origination, different, forge, vives, capita,
# Nearest to no: any, little, ramanujan, dodgson, yerushalmi, anni, juneau, sessions,
# Nearest to many: several, some, numerous, various, these, all, those, few,
# Nearest to th: bc, rd, nd, bce, dz, one, second, gerson,
# Nearest to would: will, could, might, may, should, can, must, cannot,
# Nearest to during: in, after, through, before, at, throughout, within, under,
# Nearest to most: more, less, especially, beaton, many, some, both, among,
# Nearest to this: which, it, another, itself, he, what, the, some,
# Nearest to his: her, their, our, my, your, its, the, s,
# Done.

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
print('Done.')
# Out:
# Done.

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
print('Done.')
# Out:
# Done.

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
#The model proposed is such simple in getting contexts so we can just swap labels and inputs to get CBOW analogy
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        # WOW SUCH CBOW
        batch_labels, batch_data = generate_batch(batch_size, num_skips, skip_window)
        batch_data = batch_data.reshape((batch_size,))
        batch_labels = batch_labels.reshape((batch_size, 1))
        
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
print('Done.')
# Out:
# WARNING:tensorflow:From <ipython-input-11-3780a62101bd>:4: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.497414
# Nearest to been: nile, monolith, rebranded, papeete, motet, doubts, unsigned, amway,
# Nearest to state: oppressive, chee, subdivisions, ripening, orphanage, flynt, undefeated, glued,
# Nearest to about: sibilant, ease, libration, egypt, electronica, blissymbolics, dennis, chairperson,
# Nearest to an: appreciative, portal, signaling, drexler, unsatisfied, intelligentsia, valproate, investments,
# Nearest to there: denny, adversely, clashed, ocular, starving, zhang, mindedness, superheroes,
# Nearest to by: documentary, rae, ayckbourn, clergy, slept, demoscene, scorpio, cbe,
# Nearest to who: terminology, khalq, corn, modularity, arabized, amalgamated, chemically, collaboration,
# Nearest to new: diabetic, diocletian, edmonds, deconstructing, stupidity, varies, neologisms, objections,
# Nearest to no: laissez, shelley, ajax, dct, jell, ayn, hippolyte, sheeana,
# Nearest to many: days, agathocles, albury, blizzard, navier, kam, quotients, litters,
# Nearest to th: sir, imposed, journals, qwerty, reed, proudly, galindo, col,
# Nearest to would: modernisation, serves, marcantonio, cosmetics, throats, pers, ido, nobles,
# Nearest to during: aide, communicator, bastions, hallstatt, abolitionists, traitor, stops, reconciled,
# Nearest to most: pine, plugins, dirt, optimistic, auks, herculaneum, unison, giants,
# Nearest to this: proudhon, satsuma, lightsabers, herders, dione, devoting, martha, vein,
# Nearest to his: spirituality, experiments, enact, mips, jewry, without, appendicitis, trial,
# Average loss at step 2000: 4.379356
# Average loss at step 4000: 3.876926
# Average loss at step 6000: 3.800309
# Average loss at step 8000: 3.755286
# Average loss at step 10000: 3.624563
# Nearest to been: rebranded, papeete, decades, was, motet, dangling, palembang, atlanta,
# Nearest to state: oppressive, flynt, dandyism, chee, vicinity, precursors, glued, dubbing,
# Nearest to about: egypt, sibilant, dilated, where, printout, leveraged, yerushalayim, specialized,
# Nearest to an: ferruccio, portal, zombies, aikman, townes, unsatisfied, rectifier, ulvaeus,
# Nearest to there: it, hymen, denny, arana, statics, dirt, adversely, postings,
# Nearest to by: was, with, and, in, is, demoscene, cbe, for,
# Nearest to who: tursiops, terminology, they, he, unravel, pirin, scholz, often,
# Nearest to new: solely, diabetic, substitutions, exponentiation, intimidating, edmonds, varies, platt,
# Nearest to no: shelley, laissez, snowball, ajax, a, hao, verhofstadt, choose,
# Nearest to many: some, blizzard, octavio, glossary, all, bat, ghq, kam,
# Nearest to th: sir, ece, col, dorado, repository, imposed, unambiguously, mentha,
# Nearest to would: can, could, will, may, calamity, kana, pers, modernisation,
# Nearest to during: laban, rickenbacker, hamel, by, abolitionists, skyrocketed, uniformity, after,
# Nearest to most: dirt, giants, collegium, pine, preparedness, creation, many, mathematics,
# Nearest to this: it, which, the, diodorus, tabulation, its, that, their,
# Nearest to his: their, its, avars, the, jewry, assumes, regard, prison,
# Average loss at step 12000: 3.581646
# Average loss at step 14000: 3.611502
# Average loss at step 16000: 3.584843
# Average loss at step 18000: 3.571093
# Average loss at step 20000: 3.553492
# Nearest to been: was, be, rebranded, dangling, by, harder, had, dessau,
# Nearest to state: density, vicinity, flynt, oppressive, conservation, pomeranian, dandyism, barbie,
# Nearest to about: printout, sibilant, yerushalayim, specialized, gmbh, better, sh, intentions,
# Nearest to an: ferruccio, edition, lux, suffers, the, dmitry, unsatisfied, lagoons,
# Nearest to there: it, they, he, often, aristocrat, statics, still, sardis,
# Nearest to by: be, from, with, was, wrapping, as, laminar, been,
# Nearest to who: he, she, tursiops, they, often, which, that, also,
# Nearest to new: swedish, diabetic, substitutions, dana, political, diversity, norodom, clitoris,
# Nearest to no: shelley, exhibition, snowball, nurses, it, pura, dakota, sparingly,
# Nearest to many: some, several, these, all, most, various, glossary, credentials,
# Nearest to th: col, ece, sir, unambiguously, mentha, dorado, kaufmann, resort,
# Nearest to would: will, could, can, may, must, should, might, shall,
# Nearest to during: after, in, at, laban, upon, rickenbacker, for, dreamers,
# Nearest to most: more, many, collegium, preparedness, creation, dirt, pine, auks,
# Nearest to this: it, which, diodorus, lying, what, decrypt, tabulation, the,
# Nearest to his: their, her, its, the, s, our, interlingua, trial,
# Average loss at step 22000: 3.526874
# Average loss at step 24000: 3.441038
# Average loss at step 26000: 3.420046
# Average loss at step 28000: 3.473456
# Average loss at step 30000: 3.406797
# Nearest to been: be, become, was, dessau, were, already, rebranded, dangling,
# Nearest to state: vicinity, density, form, dandyism, oppressive, flynt, manfred, applicative,
# Nearest to about: gmbh, sibilant, encloses, presse, sh, populate, specialized, yerushalayim,
# Nearest to an: manpower, portal, suffers, dirham, lagoons, fermium, popped, compactification,
# Nearest to there: it, they, he, often, this, still, now, also,
# Nearest to by: with, contends, cbe, was, under, demoscene, be, wrapping,
# Nearest to who: he, she, and, which, they, px, often, attractors,
# Nearest to new: diabetic, tyrell, substitutions, solely, deconstructing, dana, monist, objections,
# Nearest to no: exhibition, corroborating, any, it, anthologized, a, or, pura,
# Nearest to many: some, several, these, various, all, those, both, most,
# Nearest to th: ece, col, sir, unambiguously, kaufmann, tet, resort, mentha,
# Nearest to would: could, will, can, may, must, should, might, cannot,
# Nearest to during: in, after, at, upon, abolitionists, second, gv, longford,
# Nearest to most: more, some, creation, many, collegium, cruisers, revival, preparedness,
# Nearest to this: it, which, there, diodorus, the, each, mtr, any,
# Nearest to his: their, her, its, the, our, your, redistricting, cfcs,
# Average loss at step 32000: 3.418150
# Average loss at step 34000: 3.435934
# Average loss at step 36000: 3.364403
# Average loss at step 38000: 3.495866
# Average loss at step 40000: 3.444352
# Nearest to been: become, be, was, were, dessau, airfields, already, never,
# Nearest to state: vicinity, vice, density, government, manfred, form, swallowing, dandyism,
# Nearest to about: presse, gmbh, sibilant, cancellation, interlingua, waldensians, encloses, ease,
# Nearest to an: lux, ferruccio, the, portal, manpower, harpists, fermium, townes,
# Nearest to there: it, they, he, still, we, now, often, postings,
# Nearest to by: wrapping, with, osteoblasts, cbe, laminar, be, demoscene, dangling,
# Nearest to who: he, they, she, often, which, transmissions, tradeoffs, moribund,
# Nearest to new: solely, endowment, substitutions, czes, clitoris, tyrell, intimidating, diabetic,
# Nearest to no: a, any, currently, anthologized, corroborating, nurses, josie, itself,
# Nearest to many: some, several, these, various, other, all, those, both,
# Nearest to th: ece, tet, mph, nineteenth, sir, unambiguously, resort, col,
# Nearest to would: will, could, can, may, must, should, might, cannot,
# Nearest to during: after, in, upon, at, competent, when, throughout, through,
# Nearest to most: more, many, creation, less, particularly, collegium, some, revival,
# Nearest to this: which, it, diodorus, that, some, the, any, their,
# Nearest to his: their, her, its, our, the, my, s, your,
# Average loss at step 42000: 3.427504
# Average loss at step 44000: 3.274494
# Average loss at step 46000: 3.406864
# Average loss at step 48000: 3.434237
# Average loss at step 50000: 3.434732
# Nearest to been: become, be, was, grown, were, dessau, already, airfields,
# Nearest to state: vicinity, government, vice, density, aldermen, swallowing, manfred, politicians,
# Nearest to about: sibilant, presse, ease, gmbh, marauders, specialized, encloses, fooled,
# Nearest to an: ferruccio, townes, lux, unfold, fermium, manpower, portal, compactification,
# Nearest to there: they, it, still, he, we, often, now, usually,
# Nearest to by: wrapping, was, ica, with, osteoblasts, cbe, demoscene, laminar,
# Nearest to who: he, she, attractors, which, iala, they, often, px,
# Nearest to new: czes, summary, deconstructing, monist, swedish, locking, substitutions, hacker,
# Nearest to no: any, corroborating, a, positive, lacanian, cleanse, exhibition, nurses,
# Nearest to many: some, several, various, these, all, most, other, those,
# Nearest to th: ece, tet, kaufmann, stomach, nineteenth, sir, one, five,
# Nearest to would: will, could, can, may, must, should, might, cannot,
# Nearest to during: after, in, when, at, upon, of, longford, competent,
# Nearest to most: more, many, creation, some, assertive, less, revival, several,
# Nearest to this: which, it, diodorus, moulin, each, reared, the, lying,
# Nearest to his: her, their, its, your, our, my, the, s,
# Average loss at step 52000: 3.452932
# Average loss at step 54000: 3.431570
# Average loss at step 56000: 3.409507
# Average loss at step 58000: 3.282052
# Average loss at step 60000: 3.381218
# Nearest to been: be, become, were, was, grown, already, rebranded, dessau,
# Nearest to state: government, vicinity, swallowing, density, vice, politicians, timpani, angie,
# Nearest to about: gmbh, over, sibilant, interlingua, ease, presse, marauders, fooled,
# Nearest to an: manpower, portal, harpists, ferruccio, compactification, lux, townes, fc,
# Nearest to there: it, they, he, still, we, she, now, also,
# Nearest to by: wrapping, osteoblasts, in, demoscene, cbe, laminar, against, from,
# Nearest to who: he, which, she, transmissions, also, often, they, attractors,
# Nearest to new: czes, hacker, swedish, monist, different, wallpaper, resupply, substitutions,
# Nearest to no: any, corroborating, another, nurses, positive, little, itself, modernization,
# Nearest to many: some, several, various, these, all, other, most, those,
# Nearest to th: four, nineteenth, tet, ece, kaufmann, nd, stomach, eight,
# Nearest to would: could, will, can, must, may, should, might, shall,
# Nearest to during: after, in, before, at, upon, throughout, longford, competent,
# Nearest to most: more, many, some, creation, among, all, less, several,
# Nearest to this: which, it, that, diodorus, another, the, each, moulin,
# Nearest to his: her, their, its, the, my, your, our, whose,
# Average loss at step 62000: 3.443192
# Average loss at step 64000: 3.362411
# Average loss at step 66000: 3.343571
# Average loss at step 68000: 3.387691
# Average loss at step 70000: 3.373439
# Nearest to been: become, be, were, grown, was, already, being, dangling,
# Nearest to state: government, vicinity, swallowing, mediators, politicians, majority, density, swans,
# Nearest to about: marauders, fooled, gmbh, populate, approximately, rpgs, presse, sibilant,
# Nearest to an: ferruccio, manpower, portal, townes, unfold, compactification, coburg, afonso,
# Nearest to there: it, they, still, he, we, she, however, also,
# Nearest to by: wrapping, was, demoscene, be, through, laminar, osteoblasts, in,
# Nearest to who: he, she, which, often, still, they, transmissions, attractors,
# Nearest to new: czes, bub, single, endowment, deconstructing, dervish, penn, monist,
# Nearest to no: little, any, another, corroborating, lacanian, positive, allophone, duplicates,
# Nearest to many: several, some, various, these, both, all, most, those,
# Nearest to th: eight, four, seven, six, five, nineteenth, rd, births,
# Nearest to would: could, will, can, must, may, should, might, cannot,
# Nearest to during: after, in, before, at, throughout, until, longford, upon,
# Nearest to most: more, among, many, particularly, creation, all, some, several,
# Nearest to this: which, it, diodorus, the, moulin, each, another, that,
# Nearest to his: her, their, its, my, your, our, whose, the,
# Average loss at step 72000: 3.400981
# Average loss at step 74000: 3.381222
# Average loss at step 76000: 3.349989
# Average loss at step 78000: 3.237204
# Average loss at step 80000: 3.374134
# Nearest to been: become, be, already, grown, was, being, dangling, were,
# Nearest to state: government, states, mediators, vice, sigismund, swans, golding, faculty,
# Nearest to about: approximately, marauders, ease, gmbh, over, fooled, rpgs, brac,
# Nearest to an: dirham, pcb, manpower, antipsychotics, apiece, the, rectifier, grating,
# Nearest to there: they, it, we, she, he, now, still, usually,
# Nearest to by: through, wrapping, laminar, osteoblasts, against, cbe, using, without,
# Nearest to who: he, she, which, often, they, transmissions, levitation, honda,
# Nearest to new: different, czes, tyrell, bub, single, deconstructing, resupply, endowment,
# Nearest to no: little, any, another, positive, josie, pardoned, corroborating, lacanian,
# Nearest to many: several, some, various, these, most, both, few, those,
# Nearest to th: nineteenth, mph, births, ece, five, rd, isbn, resort,
# Nearest to would: could, will, can, may, must, might, should, cannot,
# Nearest to during: after, before, in, at, within, throughout, until, when,
# Nearest to most: more, some, many, majored, particularly, several, among, all,
# Nearest to this: which, it, the, another, each, reared, any, diodorus,
# Nearest to his: her, their, its, my, your, the, our, whose,
# Average loss at step 82000: 3.298971
# Average loss at step 84000: 3.342898
# Average loss at step 86000: 3.353531
# Average loss at step 88000: 3.317558
# Average loss at step 90000: 3.243124
# Nearest to been: become, be, was, already, were, grown, had, dangling,
# Nearest to state: states, vice, government, faculty, golding, mediators, swans, angie,
# Nearest to about: marauders, over, on, approximately, populate, fooled, sibilant, bacterium,
# Nearest to an: ferruccio, unfold, afonso, another, jacobean, manpower, harpists, portal,
# Nearest to there: it, they, she, he, we, still, often, now,
# Nearest to by: wrapping, demoscene, when, through, with, osteoblasts, cbe, magdalene,
# Nearest to who: which, he, she, also, often, transmissions, but, levitation,
# Nearest to new: tyrell, swedish, bub, czes, deconstructing, dervish, endowment, damnation,
# Nearest to no: little, any, statutory, another, corroborating, josie, duplex, lacanian,
# Nearest to many: some, several, various, these, numerous, all, those, few,
# Nearest to th: nineteenth, one, ece, mph, zilog, jonas, resort, col,
# Nearest to would: could, will, can, might, must, may, should, did,
# Nearest to during: after, in, at, before, within, throughout, until, following,
# Nearest to most: more, many, some, among, all, majored, particularly, stefan,
# Nearest to this: which, it, another, each, diodorus, the, some, that,
# Nearest to his: her, their, its, my, your, our, the, s,
# Average loss at step 92000: 2.740864
# Average loss at step 94000: 3.101658
# Average loss at step 96000: 3.063792
# Average loss at step 98000: 3.222676
# Average loss at step 100000: 3.278887
# Nearest to been: become, be, already, was, grown, were, dangling, recently,
# Nearest to state: states, government, vice, faculty, city, golding, domestic, disproportionately,
# Nearest to about: marauders, fooled, sibilant, godfather, gmbh, on, aragonese, rpgs,
# Nearest to an: manpower, another, ferruccio, harpists, fermium, unfold, jacobean, afonso,
# Nearest to there: it, they, still, she, he, we, often, sometimes,
# Nearest to by: with, osteoblasts, cbe, without, wrapping, laminar, against, using,
# Nearest to who: often, he, which, transmissions, she, also, usually, still,
# Nearest to new: different, czes, tyrell, bub, druidism, dervish, buckinghamshire, deconstructing,
# Nearest to no: little, any, another, lacanian, she, corroborating, josie, statutory,
# Nearest to many: some, several, various, these, both, numerous, those, multiple,
# Nearest to th: resort, nineteenth, ece, mph, rd, participates, nd, sanctus,
# Nearest to would: could, will, can, might, must, may, should, did,
# Nearest to during: after, in, at, under, before, within, throughout, following,
# Nearest to most: more, among, many, some, especially, particularly, equinox, majored,
# Nearest to this: which, it, the, another, diodorus, some, each, there,
# Nearest to his: her, their, its, my, your, our, the, whose,
# Done.

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
print('Done.')

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
print('Done.')
# Out:
# Done.
# Done.
